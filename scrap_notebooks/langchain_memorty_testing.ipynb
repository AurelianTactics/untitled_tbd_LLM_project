# %%
# https://python.langchain.com/docs/modules/memory/types/buffer_window
'''
In this example embeds in a conversation chain
from langchain_openai import OpenAI
from langchain.chains import ConversationChain
conversation_with_summary = ConversationChain(
    llm=OpenAI(temperature=0),
    # We set a low k=2, to only keep the last 2 interactions in memory
    memory=ConversationBufferWindowMemory(k=2),
    verbose=True
)
conversation_with_summary.predict(input="Hi, what's up?")
'''

#https://python.langchain.com/docs/modules/memory/types/buffer



#https://python.langchain.com/docs/expression_language/cookbook/memory
'''
in this example embeds in a prompt

from operator import itemgetter

from langchain.memory import ConversationBufferMemory
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_openai import ChatOpenAI

model = ChatOpenAI()
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful chatbot"),
        MessagesPlaceholder(variable_name="history"),
        ("human", "{input}"),
    ]
)

'''

#https://python.langchain.com/docs/modules/memory/types/entity_summary_memory
'''
can build up info on an entity over time
'''

#https://api.python.langchain.com/en/latest/chains/langchain.chains.conversational_retrieval.base.ConversationalRetrievalChain.html#langchain.chains.conversational_retrieval.base.ConversationalRetrievalChain
'''
Is also a conversationalretreivalchain that works RAG into conversationchain
'''

#https://python.langchain.com/docs/expression_language/cookbook/retrieval
'''
Example with RAG
'''
